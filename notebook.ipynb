# %% [markdown]
# ## 1. American Sign Language (ASL)
# <p>American Sign Language (ASL) is the primary language used by many deaf individuals in North America, and it is also used by hard-of-hearing and hearing individuals.  The language is as rich as spoken languages and employs signs made with the hand, along with facial gestures and bodily postures.</p>
# <p><img src="https://assets.datacamp.com/production/project_509/img/asl.png" alt="american sign language"></p>
# <p>A lot of recent progress has been made towards developing computer vision systems that translate sign language to spoken language.  This technology  often relies on complex neural network architectures that can detect subtle patterns in streaming video.  However, as a first step, towards understanding how to build a translation system, we can reduce the size of the problem by translating individual letters, instead of sentences.</p>
# <p><strong>In this notebook</strong>, we will train a convolutional neural network to classify images of American Sign Language (ASL) letters.  After loading, examining, and preprocessing the data, we will train the network and test its performance.</p>
# <p>In the code cell below, we load the training and test data. </p>
# <ul>
# <li><code>x_train</code> and <code>x_test</code> are arrays of image data with shape <code>(num_samples, 3, 50, 50)</code>, corresponding to the training and test datasets, respectively.</li>
# <li><code>y_train</code> and <code>y_test</code> are arrays of category labels with shape <code>(num_samples,)</code>, corresponding to the training and test datasets, respectively.</li>
# </ul>

# %%
# !unzip datasets/A.zip -d datasets
# !unzip datasets/B.zip -d datasets
# !unzip datasets/C.zip -d datasets
# Out:
# Archive:  datasets/A.zip
#    creating: datasets/A/
#   inflating: datasets/A/A25.jpg
#   inflating: datasets/A/A618.jpg
#   inflating: datasets/A/A31.jpg
#   inflating: datasets/A/A142.jpg
#   inflating: datasets/A/A19.jpg
#   inflating: datasets/A/A624.jpg
#   inflating: datasets/A/A630.jpg
#   inflating: datasets/A/A156.jpg
#   inflating: datasets/A/A803.jpg
#   inflating: datasets/A/A817.jpg
#   inflating: datasets/A/A181.jpg
#   inflating: datasets/A/A195.jpg
#   inflating: datasets/A/A368.jpg
#   inflating: datasets/A/A426.jpg
#   inflating: datasets/A/A340.jpg
#   inflating: datasets/A/A354.jpg
#   inflating: datasets/A/A432.jpg
#   inflating: datasets/A/A383.jpg
#   inflating: datasets/A/A397.jpg
#   inflating: datasets/A/A208.jpg
#   inflating: datasets/A/A552.jpg
#   inflating: datasets/A/A234.jpg
#   inflating: datasets/A/A220.jpg
#   inflating: datasets/A/A546.jpg
#   inflating: datasets/A/A591.jpg
#   inflating: datasets/A/A585.jpg
#   inflating: datasets/A/A778.jpg
#   inflating: datasets/A/A988.jpg
#   inflating: datasets/A/A750.jpg
#   inflating: datasets/A/A744.jpg
#   inflating: datasets/A/A977.jpg
#   inflating: datasets/A/A963.jpg
#   inflating: datasets/A/A793.jpg
#   inflating: datasets/A/A787.jpg
#   inflating: datasets/A/A786.jpg
#   inflating: datasets/A/A792.jpg
#   inflating: datasets/A/A962.jpg
#   inflating: datasets/A/A976.jpg
#   inflating: datasets/A/A745.jpg
#   inflating: datasets/A/A751.jpg
#   inflating: datasets/A/A989.jpg
#   inflating: datasets/A/A779.jpg
#   inflating: datasets/A/A584.jpg
#   inflating: datasets/A/A590.jpg
#   inflating: datasets/A/A221.jpg
#   inflating: datasets/A/A547.jpg
#   inflating: datasets/A/A553.jpg
#   inflating: datasets/A/A235.jpg
#   inflating: datasets/A/A209.jpg
#   inflating: datasets/A/A396.jpg
#   inflating: datasets/A/A382.jpg
#   inflating: datasets/A/A355.jpg
#   inflating: datasets/A/A433.jpg
#   inflating: datasets/A/A427.jpg
#   inflating: datasets/A/A341.jpg
#   inflating: datasets/A/A369.jpg
#   inflating: datasets/A/A194.jpg
#   inflating: datasets/A/A180.jpg
#   inflating: datasets/A/A816.jpg
#   inflating: datasets/A/A802.jpg
#   inflating: datasets/A/A1.jpg
#   inflating: datasets/A/A631.jpg
#   inflating: datasets/A/A157.jpg
#   inflating: datasets/A/A18.jpg
#   inflating: datasets/A/A143.jpg
#   inflating: datasets/A/A625.jpg
#   inflating: datasets/A/A30.jpg
#   inflating: datasets/A/A24.jpg
#   inflating: datasets/A/A619.jpg
#   inflating: datasets/A/A169.jpg
#   inflating: datasets/A/A32.jpg
#   inflating: datasets/A/A26.jpg
#   inflating: datasets/A/A155.jpg
#   inflating: datasets/A/A633.jpg
#   inflating: datasets/A/A3.jpg
#   inflating: datasets/A/A627.jpg
#   inflating: datasets/A/A141.jpg
#   inflating: datasets/A/A814.jpg
#   inflating: datasets/A/A800.jpg
#   inflating: datasets/A/A196.jpg
#   inflating: datasets/A/A828.jpg
#   inflating: datasets/A/A182.jpg
#   inflating: datasets/A/A419.jpg
#   inflating: datasets/A/A431.jpg
#   inflating: datasets/A/A357.jpg
#   inflating: datasets/A/A343.jpg
#   inflating: datasets/A/A425.jpg
#   inflating: datasets/A/A394.jpg
#   inflating: datasets/A/A380.jpg
#   inflating: datasets/A/A579.jpg
#   inflating: datasets/A/A545.jpg
#   inflating: datasets/A/A223.jpg
#   inflating: datasets/A/A237.jpg
#   inflating: datasets/A/A551.jpg
#   inflating: datasets/A/A586.jpg
#   inflating: datasets/A/A592.jpg
#   inflating: datasets/A/A747.jpg
#   inflating: datasets/A/A753.jpg
#   inflating: datasets/A/A960.jpg
#   inflating: datasets/A/A974.jpg
#   inflating: datasets/A/A784.jpg
#   inflating: datasets/A/A790.jpg
#   inflating: datasets/A/A948.jpg
#   inflating: datasets/A/A949.jpg
#   inflating: datasets/A/A791.jpg
#   inflating: datasets/A/A785.jpg
#   inflating: datasets/A/A975.jpg
#   inflating: datasets/A/A961.jpg
#   inflating: datasets/A/A752.jpg
#   inflating: datasets/A/A746.jpg
#   inflating: datasets/A/A593.jpg
#   inflating: datasets/A/A587.jpg
#   inflating: datasets/A/A236.jpg
#   inflating: datasets/A/A550.jpg
#   inflating: datasets/A/A544.jpg
#   inflating: datasets/A/A222.jpg
#   inflating: datasets/A/A578.jpg
#   inflating: datasets/A/A381.jpg
#   inflating: datasets/A/A395.jpg
#   inflating: datasets/A/A342.jpg
#   inflating: datasets/A/A424.jpg
#   inflating: datasets/A/A430.jpg
#   inflating: datasets/A/A356.jpg
#   inflating: datasets/A/A418.jpg
#   inflating: datasets/A/A183.jpg
#   inflating: datasets/A/A197.jpg
#   inflating: datasets/A/A829.jpg
#   inflating: datasets/A/A1000.jpg
#   inflating: datasets/A/A801.jpg
#   inflating: datasets/A/A815.jpg
#   inflating: datasets/A/A626.jpg
#   inflating: datasets/A/A140.jpg
#   inflating: datasets/A/A154.jpg
#   inflating: datasets/A/A2.jpg
#   inflating: datasets/A/A632.jpg
#   inflating: datasets/A/A27.jpg
#   inflating: datasets/A/A33.jpg
#   inflating: datasets/A/A168.jpg
#   inflating: datasets/A/A636.jpg
#   inflating: datasets/A/A6.jpg
#   inflating: datasets/A/A150.jpg
#   inflating: datasets/A/A144.jpg
#   inflating: datasets/A/A622.jpg
#   inflating: datasets/A/A37.jpg
#   inflating: datasets/A/A23.jpg
#   inflating: datasets/A/A178.jpg
#   inflating: datasets/A/A193.jpg
#   inflating: datasets/A/A187.jpg
#   inflating: datasets/A/A839.jpg
#   inflating: datasets/A/A811.jpg
#   inflating: datasets/A/A805.jpg
#   inflating: datasets/A/A352.jpg
#   inflating: datasets/A/A434.jpg
#   inflating: datasets/A/A420.jpg
#   inflating: datasets/A/A346.jpg
#   inflating: datasets/A/A408.jpg
#   inflating: datasets/A/A391.jpg
#   inflating: datasets/A/A385.jpg
#   inflating: datasets/A/A226.jpg
#   inflating: datasets/A/A540.jpg
#   inflating: datasets/A/A554.jpg
#   inflating: datasets/A/A232.jpg
#   inflating: datasets/A/A568.jpg
#   inflating: datasets/A/A583.jpg
#   inflating: datasets/A/A597.jpg
#   inflating: datasets/A/A742.jpg
#   inflating: datasets/A/A756.jpg
#   inflating: datasets/A/A781.jpg
#   inflating: datasets/A/A959.jpg
#   inflating: datasets/A/A795.jpg
#   inflating: datasets/A/A965.jpg
#   inflating: datasets/A/A971.jpg
#   inflating: datasets/A/A970.jpg
#   inflating: datasets/A/A964.jpg
#   inflating: datasets/A/A794.jpg
#   inflating: datasets/A/A958.jpg
#   inflating: datasets/A/A780.jpg
#   inflating: datasets/A/A757.jpg
#   inflating: datasets/A/A743.jpg
#   inflating: datasets/A/A596.jpg
#   inflating: datasets/A/A582.jpg
#   inflating: datasets/A/A569.jpg
#   inflating: datasets/A/A555.jpg
#   inflating: datasets/A/A233.jpg
#   inflating: datasets/A/A227.jpg
#   inflating: datasets/A/A541.jpg
#   inflating: datasets/A/A384.jpg
#   inflating: datasets/A/A390.jpg
#   inflating: datasets/A/A409.jpg
#   inflating: datasets/A/A421.jpg
#   inflating: datasets/A/A347.jpg
#   inflating: datasets/A/A353.jpg
#   inflating: datasets/A/A435.jpg
#   inflating: datasets/A/A804.jpg
#   inflating: datasets/A/A810.jpg
#   inflating: datasets/A/A186.jpg
#   inflating: datasets/A/A838.jpg
#   inflating: datasets/A/A192.jpg
#   inflating: datasets/A/A179.jpg
#   inflating: datasets/A/A22.jpg
#   inflating: datasets/A/A36.jpg
#   inflating: datasets/A/A145.jpg
#   inflating: datasets/A/A623.jpg
#   inflating: datasets/A/A7.jpg
#   inflating: datasets/A/A637.jpg
#   inflating: datasets/A/A151.jpg
#   inflating: datasets/A/A621.jpg
#   inflating: datasets/A/A147.jpg
#   inflating: datasets/A/A153.jpg
#   inflating: datasets/A/A635.jpg
#   inflating: datasets/A/A5.jpg
#   inflating: datasets/A/A20.jpg
#   inflating: datasets/A/A34.jpg
#   inflating: datasets/A/A609.jpg
#   inflating: datasets/A/A184.jpg
#   inflating: datasets/A/A190.jpg
#   inflating: datasets/A/A806.jpg
#   inflating: datasets/A/A812.jpg
#   inflating: datasets/A/A345.jpg
#   inflating: datasets/A/A423.jpg
#   inflating: datasets/A/A437.jpg
#   inflating: datasets/A/A351.jpg
#   inflating: datasets/A/A379.jpg
#   inflating: datasets/A/A386.jpg
#   inflating: datasets/A/A392.jpg
#   inflating: datasets/A/A231.jpg
#   inflating: datasets/A/A557.jpg
#   inflating: datasets/A/A543.jpg
#   inflating: datasets/A/A225.jpg
#   inflating: datasets/A/A219.jpg
#   inflating: datasets/A/A594.jpg
#   inflating: datasets/A/A580.jpg
#   inflating: datasets/A/A755.jpg
#   inflating: datasets/A/A999.jpg
#   inflating: datasets/A/A741.jpg
#   inflating: datasets/A/A769.jpg
#   inflating: datasets/A/A796.jpg
#   inflating: datasets/A/A782.jpg
#   inflating: datasets/A/A972.jpg
#   inflating: datasets/A/A966.jpg
#   inflating: datasets/A/A967.jpg
#   inflating: datasets/A/A973.jpg
#   inflating: datasets/A/A783.jpg
#   inflating: datasets/A/A797.jpg
#   inflating: datasets/A/A768.jpg
#   inflating: datasets/A/A740.jpg
#   inflating: datasets/A/A998.jpg
#   inflating: datasets/A/A754.jpg
#   inflating: datasets/A/A581.jpg
#   inflating: datasets/A/A595.jpg
#   inflating: datasets/A/A218.jpg
#   inflating: datasets/A/A542.jpg
#   inflating: datasets/A/A224.jpg
#   inflating: datasets/A/A230.jpg
#   inflating: datasets/A/A556.jpg
#   inflating: datasets/A/A393.jpg
#   inflating: datasets/A/A387.jpg
#   inflating: datasets/A/A378.jpg
#   inflating: datasets/A/A436.jpg
#   inflating: datasets/A/A350.jpg
#   inflating: datasets/A/A344.jpg
#   inflating: datasets/A/A422.jpg
#   inflating: datasets/A/A813.jpg
#   inflating: datasets/A/A807.jpg
#   inflating: datasets/A/A191.jpg
#   inflating: datasets/A/A185.jpg
#   inflating: datasets/A/A35.jpg
#   inflating: datasets/A/A608.jpg
#   inflating: datasets/A/A21.jpg
#   inflating: datasets/A/A152.jpg
#   inflating: datasets/A/A4.jpg
#   inflating: datasets/A/A634.jpg
#   inflating: datasets/A/A620.jpg
#   inflating: datasets/A/A146.jpg
#   inflating: datasets/A/A46.jpg
#   inflating: datasets/A/A52.jpg
#   inflating: datasets/A/A109.jpg
#   inflating: datasets/A/A647.jpg
#   inflating: datasets/A/A121.jpg
#   inflating: datasets/A/A135.jpg
#   inflating: datasets/A/A653.jpg
#   inflating: datasets/A/A860.jpg
#   inflating: datasets/A/A85.jpg
#   inflating: datasets/A/A91.jpg
#   inflating: datasets/A/A874.jpg
#   inflating: datasets/A/A684.jpg
#   inflating: datasets/A/A848.jpg
#   inflating: datasets/A/A690.jpg
#   inflating: datasets/A/A479.jpg
#   inflating: datasets/A/A323.jpg
#   inflating: datasets/A/A445.jpg
#   inflating: datasets/A/A451.jpg
#   inflating: datasets/A/A337.jpg
#   inflating: datasets/A/A486.jpg
#   inflating: datasets/A/A492.jpg
#   inflating: datasets/A/A519.jpg
#   inflating: datasets/A/A257.jpg
#   inflating: datasets/A/A531.jpg
#   inflating: datasets/A/A525.jpg
#   inflating: datasets/A/A243.jpg
#   inflating: datasets/A/A294.jpg
#   inflating: datasets/A/A280.jpg
#   inflating: datasets/A/A733.jpg
#   inflating: datasets/A/A727.jpg
#   inflating: datasets/A/A914.jpg
#   inflating: datasets/A/A900.jpg
#   inflating: datasets/A/A928.jpg
#   inflating: datasets/A/A929.jpg
#   inflating: datasets/A/A901.jpg
#   inflating: datasets/A/A915.jpg
#   inflating: datasets/A/A726.jpg
#   inflating: datasets/A/A732.jpg
#   inflating: datasets/A/A281.jpg
#   inflating: datasets/A/A295.jpg
#   inflating: datasets/A/A524.jpg
#   inflating: datasets/A/A242.jpg
#   inflating: datasets/A/A256.jpg
#   inflating: datasets/A/A530.jpg
#   inflating: datasets/A/A518.jpg
#   inflating: datasets/A/A493.jpg
#   inflating: datasets/A/A487.jpg
#   inflating: datasets/A/A450.jpg
#   inflating: datasets/A/A336.jpg
#   inflating: datasets/A/A322.jpg
#   inflating: datasets/A/A444.jpg
#   inflating: datasets/A/A478.jpg
#   inflating: datasets/A/A691.jpg
#   inflating: datasets/A/A849.jpg
#   inflating: datasets/A/A685.jpg
#   inflating: datasets/A/A90.jpg
#   inflating: datasets/A/A875.jpg
#   inflating: datasets/A/A861.jpg
#   inflating: datasets/A/A84.jpg
#   inflating: datasets/A/A134.jpg
#   inflating: datasets/A/A652.jpg
#   inflating: datasets/A/A646.jpg
#   inflating: datasets/A/A120.jpg
#   inflating: datasets/A/A108.jpg
#   inflating: datasets/A/A53.jpg
#   inflating: datasets/A/A47.jpg
#   inflating: datasets/A/A51.jpg
#   inflating: datasets/A/A45.jpg
#   inflating: datasets/A/A678.jpg
#   inflating: datasets/A/A650.jpg
#   inflating: datasets/A/A888.jpg
#   inflating: datasets/A/A136.jpg
#   inflating: datasets/A/A79.jpg
#   inflating: datasets/A/A122.jpg
#   inflating: datasets/A/A644.jpg
#   inflating: datasets/A/A877.jpg
#   inflating: datasets/A/A92.jpg
#   inflating: datasets/A/A86.jpg
#   inflating: datasets/A/A863.jpg
#   inflating: datasets/A/A693.jpg
#   inflating: datasets/A/A687.jpg
#   inflating: datasets/A/A308.jpg
#   inflating: datasets/A/A334.jpg
#   inflating: datasets/A/A452.jpg
#   inflating: datasets/A/A446.jpg
#   inflating: datasets/A/A320.jpg
#   inflating: datasets/A/A491.jpg
#   inflating: datasets/A/A485.jpg
#   inflating: datasets/A/A268.jpg
#   inflating: datasets/A/A240.jpg
#   inflating: datasets/A/A526.jpg
#   inflating: datasets/A/A532.jpg
#   inflating: datasets/A/A254.jpg
#   inflating: datasets/A/A283.jpg
#   inflating: datasets/A/A287.jpg
#   inflating: datasets/A/A278.jpg
#   inflating: datasets/A/A250.jpg
#   inflating: datasets/A/A536.jpg
#   inflating: datasets/A/A522.jpg
#   inflating: datasets/A/A244.jpg
#   inflating: datasets/A/A481.jpg
#   inflating: datasets/A/A495.jpg
#   inflating: datasets/A/A318.jpg
#   inflating: datasets/A/A324.jpg
#   inflating: datasets/A/A442.jpg
#   inflating: datasets/A/A456.jpg
#   inflating: datasets/A/A330.jpg
#   inflating: datasets/A/A867.jpg
#   inflating: datasets/A/A82.jpg
#   inflating: datasets/A/A96.jpg
#   inflating: datasets/A/A873.jpg
#   inflating: datasets/A/A683.jpg
#   inflating: datasets/A/A697.jpg
#   inflating: datasets/A/A41.jpg
#   inflating: datasets/A/A55.jpg
#   inflating: datasets/A/A668.jpg
#   inflating: datasets/A/A898.jpg
#   inflating: datasets/A/A640.jpg
#   inflating: datasets/A/A126.jpg
#   inflating: datasets/A/A69.jpg
#   inflating: datasets/A/A132.jpg
#   inflating: datasets/A/A654.jpg
#   inflating: datasets/A/A124.jpg
#   inflating: datasets/A/A642.jpg
#   inflating: datasets/A/A656.jpg
#   inflating: datasets/A/A130.jpg
#   inflating: datasets/A/A118.jpg
#   inflating: datasets/A/A43.jpg
#   inflating: datasets/A/A57.jpg
#   inflating: datasets/A/A859.jpg
#   inflating: datasets/A/A681.jpg
#   inflating: datasets/A/A695.jpg
#   inflating: datasets/A/A80.jpg
#   inflating: datasets/A/A865.jpg
#   inflating: datasets/A/A871.jpg
#   inflating: datasets/A/A94.jpg
#   inflating: datasets/A/A440.jpg
#   inflating: datasets/A/A326.jpg
#   inflating: datasets/A/A332.jpg
#   inflating: datasets/A/A454.jpg
#   inflating: datasets/A/A468.jpg
#   inflating: datasets/A/A483.jpg
#   inflating: datasets/A/A497.jpg
#   inflating: datasets/A/A534.jpg
#   inflating: datasets/A/A252.jpg
#   inflating: datasets/A/A246.jpg
#   inflating: datasets/A/A520.jpg
#   inflating: datasets/A/A508.jpg
#   inflating: datasets/A/A291.jpg
#   inflating: datasets/A/A285.jpg
#   inflating: datasets/A/A736.jpg
#   inflating: datasets/A/A722.jpg
#   inflating: datasets/A/A939.jpg
#   inflating: datasets/A/A911.jpg
#   inflating: datasets/A/A905.jpg
#   inflating: datasets/A/A904.jpg
#   inflating: datasets/A/A910.jpg
#   inflating: datasets/A/A938.jpg
#   inflating: datasets/A/A723.jpg
#   inflating: datasets/A/A737.jpg
#   inflating: datasets/A/A284.jpg
#   inflating: datasets/A/A290.jpg
#   inflating: datasets/A/A509.jpg
#   inflating: datasets/A/A247.jpg
#   inflating: datasets/A/A521.jpg
#   inflating: datasets/A/A535.jpg
#   inflating: datasets/A/A253.jpg
#   inflating: datasets/A/A496.jpg
#   inflating: datasets/A/A482.jpg
#   inflating: datasets/A/A469.jpg
#   inflating: datasets/A/A333.jpg
#   inflating: datasets/A/A455.jpg
#   inflating: datasets/A/A441.jpg
#   inflating: datasets/A/A327.jpg
#   inflating: datasets/A/A870.jpg
#   inflating: datasets/A/A95.jpg
#   inflating: datasets/A/A81.jpg
#   inflating: datasets/A/A864.jpg
#   inflating: datasets/A/A694.jpg
#   inflating: datasets/A/A680.jpg
#   inflating: datasets/A/A858.jpg
#   inflating: datasets/A/A56.jpg
#   inflating: datasets/A/A42.jpg
#   inflating: datasets/A/A119.jpg
#   inflating: datasets/A/A657.jpg
#   inflating: datasets/A/A131.jpg
#   inflating: datasets/A/A125.jpg
#   inflating: datasets/A/A643.jpg
#   inflating: datasets/A/A882.jpg
#   inflating: datasets/A/A67.jpg
#   inflating: datasets/A/A128.jpg
#   inflating: datasets/A/A73.jpg
#   inflating: datasets/A/A896.jpg
#   inflating: datasets/A/A666.jpg
#   inflating: datasets/A/A100.jpg
#   inflating: datasets/A/A114.jpg
#   inflating: datasets/A/A672.jpg
#   inflating: datasets/A/A841.jpg
#   inflating: datasets/A/A699.jpg
#   inflating: datasets/A/A855.jpg
#   inflating: datasets/A/A98.jpg
#   inflating: datasets/A/A869.jpg
#   inflating: datasets/A/A458.jpg
#   inflating: datasets/A/A302.jpg
#   inflating: datasets/A/A464.jpg
#   inflating: datasets/A/A470.jpg
#   inflating: datasets/A/A316.jpg
#   inflating: datasets/A/A538.jpg
#   inflating: datasets/A/A276.jpg
#   inflating: datasets/A/A510.jpg
#   inflating: datasets/A/A504.jpg
#   inflating: datasets/A/A262.jpg
#   inflating: datasets/A/A289.jpg
#   inflating: datasets/A/A712.jpg
#   inflating: datasets/A/A706.jpg
#   inflating: datasets/A/A935.jpg
#   inflating: datasets/A/A921.jpg
#   inflating: datasets/A/A909.jpg
#   inflating: datasets/A/A908.jpg
#   inflating: datasets/A/A920.jpg
#   inflating: datasets/A/A934.jpg
#   inflating: datasets/A/A707.jpg
#   inflating: datasets/A/A713.jpg
#   inflating: datasets/A/A288.jpg
#   inflating: datasets/A/A505.jpg
#   inflating: datasets/A/A263.jpg
#   inflating: datasets/A/A277.jpg
#   inflating: datasets/A/A511.jpg
#   inflating: datasets/A/A539.jpg
#   inflating: datasets/A/A471.jpg
#   inflating: datasets/A/A317.jpg
#   inflating: datasets/A/A303.jpg
#   inflating: datasets/A/A465.jpg
#   inflating: datasets/A/A459.jpg
#   inflating: datasets/A/A868.jpg
#   inflating: datasets/A/A99.jpg
#   inflating: datasets/A/A854.jpg
#   inflating: datasets/A/A698.jpg
#   inflating: datasets/A/A840.jpg
#   inflating: datasets/A/A115.jpg
#   inflating: datasets/A/A673.jpg
#   inflating: datasets/A/A667.jpg
#   inflating: datasets/A/A101.jpg
#   inflating: datasets/A/A72.jpg
#   inflating: datasets/A/A129.jpg
#   inflating: datasets/A/A897.jpg
#   inflating: datasets/A/A883.jpg
#   inflating: datasets/A/A66.jpg
#   inflating: datasets/A/A895.jpg
#   inflating: datasets/A/A70.jpg
#   inflating: datasets/A/A64.jpg
#   inflating: datasets/A/A659.jpg
#   inflating: datasets/A/A881.jpg
#   inflating: datasets/A/A671.jpg
#   inflating: datasets/A/A117.jpg
#   inflating: datasets/A/A715.jpg
#   inflating: datasets/A/A701.jpg
#   inflating: datasets/A/A259.jpg
#   inflating: datasets/A/A271.jpg
#   inflating: datasets/A/A517.jpg
#   inflating: datasets/A/A503.jpg
#   inflating: datasets/A/A265.jpg
#   inflating: datasets/A/A488.jpg
#   inflating: datasets/A/A339.jpg
#   inflating: datasets/A/A305.jpg
#   inflating: datasets/A/A463.jpg
#   inflating: datasets/A/A477.jpg
#   inflating: datasets/A/A311.jpg
#   inflating: datasets/A/A846.jpg
#   inflating: datasets/A/A852.jpg
#   inflating: datasets/A/A885.jpg
#   inflating: datasets/A/A60.jpg
#   inflating: datasets/A/A74.jpg
#   inflating: datasets/A/A891.jpg
#   inflating: datasets/A/A649.jpg
#   inflating: datasets/A/A661.jpg
#   inflating: datasets/A/A107.jpg
#   inflating: datasets/A/A113.jpg
#   inflating: datasets/A/A48.jpg
#   inflating: datasets/A/A675.jpg
#   inflating: datasets/A/A105.jpg
#   inflating: datasets/A/A663.jpg
#   inflating: datasets/A/A677.jpg
#   inflating: datasets/A/A111.jpg
#   inflating: datasets/A/A62.jpg
#   inflating: datasets/A/A139.jpg
#   inflating: datasets/A/A887.jpg
#   inflating: datasets/A/A893.jpg
#   inflating: datasets/A/A76.jpg
#   inflating: datasets/A/A878.jpg
#   inflating: datasets/A/A89.jpg
#   inflating: datasets/A/A844.jpg
#   inflating: datasets/A/A850.jpg
#   inflating: datasets/A/A688.jpg
#   inflating: datasets/A/A461.jpg
#   inflating: datasets/A/A307.jpg
#   inflating: datasets/A/A313.jpg
#   inflating: datasets/A/A475.jpg
#   inflating: datasets/A/A449.jpg
#   inflating: datasets/A/A515.jpg
#   inflating: datasets/A/A273.jpg
#   inflating: datasets/A/A267.jpg
#   inflating: datasets/A/A501.jpg
#   inflating: datasets/A/A529.jpg
#   inflating: datasets/A/A298.jpg
#   inflating: datasets/A/A717.jpg
#   inflating: datasets/A/A703.jpg
#   inflating: datasets/A/A918.jpg
#   inflating: datasets/A/A930.jpg
#   inflating: datasets/A/A924.jpg
#   inflating: datasets/A/A925.jpg
#   inflating: datasets/A/A931.jpg
#   inflating: datasets/A/A919.jpg
#   inflating: datasets/A/A702.jpg
#   inflating: datasets/A/A716.jpg
#   inflating: datasets/A/A299.jpg
#   inflating: datasets/A/A528.jpg
#   inflating: datasets/A/A266.jpg
#   inflating: datasets/A/A500.jpg
#   inflating: datasets/A/A514.jpg
#   inflating: datasets/A/A272.jpg
#   inflating: datasets/A/A448.jpg
#   inflating: datasets/A/A312.jpg
#   inflating: datasets/A/A474.jpg
#   inflating: datasets/A/A460.jpg
#   inflating: datasets/A/A306.jpg
#   inflating: datasets/A/A689.jpg
#   inflating: datasets/A/A851.jpg
#   inflating: datasets/A/A845.jpg
#   inflating: datasets/A/A88.jpg
#   inflating: datasets/A/A879.jpg
#   inflating: datasets/A/A892.jpg
#   inflating: datasets/A/A77.jpg
#   inflating: datasets/A/A138.jpg
#   inflating: datasets/A/A63.jpg
#   inflating: datasets/A/A428.jpg
#   inflating: datasets/A/A400.jpg
#   inflating: datasets/A/A366.jpg
#   inflating: datasets/A/A372.jpg
#   inflating: datasets/A/A414.jpg
#   inflating: datasets/A/A825.jpg
#   inflating: datasets/A/A831.jpg
#   inflating: datasets/A/A819.jpg
#   inflating: datasets/A/A158.jpg
#   inflating: datasets/A/A17.jpg
#   inflating: datasets/A/A164.jpg
#   inflating: datasets/A/A602.jpg
#   inflating: datasets/A/A616.jpg
#   inflating: datasets/A/A170.jpg
#   inflating: datasets/A/A600.jpg
#   inflating: datasets/A/A166.jpg
#   inflating: datasets/A/A172.jpg
#   inflating: datasets/A/A29.jpg
#   inflating: datasets/A/A614.jpg
#   inflating: datasets/A/A15.jpg
#   inflating: datasets/A/A628.jpg
#   inflating: datasets/A/A827.jpg
#   inflating: datasets/A/A199.jpg
#   inflating: datasets/A/A833.jpg
#   inflating: datasets/A/A364.jpg
#   inflating: datasets/A/A402.jpg
#   inflating: datasets/A/A416.jpg
#   inflating: datasets/A/A370.jpg
#   inflating: datasets/A/A358.jpg
#   inflating: datasets/A/A210.jpg
#   inflating: datasets/A/A576.jpg
#   inflating: datasets/A/A562.jpg
#   inflating: datasets/A/A204.jpg
#   inflating: datasets/A/A238.jpg
#   inflating: datasets/A/A589.jpg
#   inflating: datasets/A/A774.jpg
#   inflating: datasets/A/A760.jpg
#   inflating: datasets/A/A990.jpg
#   inflating: datasets/A/A748.jpg
#   inflating: datasets/A/A984.jpg
#   inflating: datasets/A/A953.jpg
#   inflating: datasets/A/A947.jpg
#   inflating: datasets/A/A946.jpg
#   inflating: datasets/A/A952.jpg
#   inflating: datasets/A/A985.jpg
#   inflating: datasets/A/A749.jpg
#   inflating: datasets/A/A991.jpg
#   inflating: datasets/A/A761.jpg
#   inflating: datasets/A/A775.jpg
#   inflating: datasets/A/A588.jpg
#   inflating: datasets/A/A239.jpg
#   inflating: datasets/A/A563.jpg
#   inflating: datasets/A/A205.jpg
#   inflating: datasets/A/A211.jpg
#   inflating: datasets/A/A577.jpg
#   inflating: datasets/A/A359.jpg
#   inflating: datasets/A/A417.jpg
#   inflating: datasets/A/A371.jpg
#   inflating: datasets/A/A365.jpg
#   inflating: datasets/A/A403.jpg
#   inflating: datasets/A/A832.jpg
#   inflating: datasets/A/A826.jpg
#   inflating: datasets/A/A198.jpg
#   inflating: datasets/A/A14.jpg
#   inflating: datasets/A/A629.jpg
#   inflating: datasets/A/A28.jpg
#   inflating: datasets/A/A173.jpg
#   inflating: datasets/A/A615.jpg
#   inflating: datasets/A/A601.jpg
#   inflating: datasets/A/A167.jpg
# Archive:  datasets/B.zip
#    creating: datasets/B/
#   inflating: datasets/B/B477.jpg
#   inflating: datasets/B/B311.jpg
#   inflating: datasets/B/B305.jpg
#   inflating: datasets/B/B463.jpg
#   inflating: datasets/B/B339.jpg
#   inflating: datasets/B/B488.jpg
#   inflating: datasets/B/B113.jpg
#   inflating: datasets/B/B675.jpg
#   inflating: datasets/B/B661.jpg
#   inflating: datasets/C/C836.jpg
#   inflating: datasets/C/C188.jpg
#   inflating: datasets/C/C837.jpg
#   inflating: datasets/C/C189.jpg
#   inflating: datasets/C/C823.jpg
#   inflating: datasets/C/C638.jpg
#   inflating: datasets/C/C610.jpg
#   inflating: datasets/C/C176.jpg
#   inflating: datasets/C/C162.jpg
#   inflating: datasets/C/C604.jpg
#   inflating: datasets/C/C348.jpg
#   inflating: datasets/C/C374.jpg
#   inflating: datasets/C/C412.jpg
#   inflating: datasets/C/C406.jpg
#   inflating: datasets/C/C360.jpg
#   inflating: datasets/C/C599.jpg
#   inflating: datasets/C/C16.jpg
#   inflating: datasets/C/C228.jpg
#   inflating: datasets/C/C200.jpg
#   inflating: datasets/C/C566.jpg
#   inflating: datasets/C/C572.jpg
#   inflating: datasets/C/C214.jpg
#   inflating: datasets/C/C943.jpg
#   inflating: datasets/C/C957.jpg
#   inflating: datasets/C/C758.jpg
#   inflating: datasets/C/C980.jpg
#   inflating: datasets/C/C994.jpg
#   inflating: datasets/C/C764.jpg
#   inflating: datasets/C/C5.jpg
#   inflating: datasets/C/C770.jpg

# %%
import random
import random
import numpy as np
from keras.utils import np_utils, to_categorical
#from keras.preprocessing.image import load_img
from tensorflow.keras.preprocessing import image
from tensorflow.keras.utils import load_img
from tensorflow.keras.utils import img_to_array
#from keras.preprocessing.image import img_to_array
from keras.models import load_model
from os import listdir
from os.path import isdir, join



def load_data(container_path='datasets', folders=['A', 'B', 'C'],
              size=2000, test_split=0.2, seed=0):
    """
    Loads sign language dataset.
    """

    filenames, labels = [], []

    for label, folder in enumerate(folders):
        folder_path = join(container_path, folder)
        images = [join(folder_path, d)
                     for d in sorted(listdir(folder_path))]
        labels.extend(len(images) * [label])
        filenames.extend(images)

    random.seed(seed)
    data = list(zip(filenames, labels))
    random.shuffle(data)
    data = data[:size]
    filenames, labels = zip(*data)


    # Get the images
    x = paths_to_tensor(filenames).astype('float32')/255
    # Store the one-hot targets
    y = np.array(labels)

    x_train = np.array(x[:int(len(x) * (1 - test_split))])
    y_train = np.array(y[:int(len(x) * (1 - test_split))])
    x_test = np.array(x[int(len(x) * (1 - test_split)):])
    y_test = np.array(y[int(len(x) * (1 - test_split)):])

    return (x_train, y_train), (x_test, y_test)


def path_to_tensor(img_path, size):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(size, size))
    # convert PIL.Image.Image type to 3D tensor
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths, size=50):
    list_of_tensors = [path_to_tensor(img_path, size) for img_path in img_paths]
    return np.vstack(list_of_tensors)


"""
    num_types = len(data['target_names'])
    targets = np_utils.to_categorical(np.array(data['target']), num_types)
"""
# Out:
# "\n    num_types = len(data['target_names'])\n    targets = np_utils.to_categorical(np.array(data['target']), num_types)\n"

# %%
# Import packages and set numpy random seed
import numpy as np
np.random.seed(5)
import tensorflow as tf
tf.random.set_seed(2)
# from datasets import sign_language
import matplotlib.pyplot as plt
# %matplotlib inline

# Load pre-shuffled training and test datasets
(x_train, y_train), (x_test, y_test) = load_data()

# %% [markdown]
# ## 2. Visualize the training data
# <p>Now we'll begin by creating a list of string-valued labels containing the letters that appear in the dataset.  Then, we visualize the first several images in the training data, along with their corresponding labels.</p>

# %%
# Store labels of dataset
labels = ['A','B','C']


# Print the first several training images, along with the labels
fig = plt.figure(figsize=(20,5))
for i in range(36):
    ax = fig.add_subplot(3, 12, i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_train[i]))
    ax.set_title("{}".format(labels[y_train[i]]))
plt.show()

# %% [markdown]
# ## 3. Examine the dataset
# <p>Let's examine how many images of each letter can be found in the dataset.</p>
# <p>Remember that dataset has already been split into training and test sets for you, where <code>x_train</code> and <code>x_test</code> contain the images, and <code>y_train</code> and <code>y_test</code> contain their corresponding labels.</p>
# <p>Each entry in <code>y_train</code> and <code>y_test</code> is one of <code>0</code>, <code>1</code>, or <code>2</code>, corresponding to the letters <code>'A'</code>, <code>'B'</code>, and <code>'C'</code>, respectively.</p>
# <p>We will use the arrays <code>y_train</code> and <code>y_test</code> to verify that both the training and test sets each have roughly equal proportions of each letter.</p>

# %%
# Number of A's in the training dataset
num_A_train = sum(y_train==0)
# Number of B's in the training dataset
num_B_train = sum(y_train==1)
# Number of C's in the training dataset
num_C_train = sum(y_train==2)

# Number of A's in the test dataset
num_A_test = sum(y_test==0)
# Number of B's in the test dataset
num_B_test = sum(y_test==1)
# Number of C's in the test dataset
num_C_test = sum(y_test==2)

# Print statistics about the dataset
print("Training set:")
print("\tA: {}, B: {}, C: {}".format(num_A_train, num_B_train, num_C_train))
print("Test set:")
print("\tA: {}, B: {}, C: {}".format(num_A_test, num_B_test, num_C_test))
# Out:
# Training set:
# 	A: 540, B: 528, C: 532
# Test set:
# 	A: 118, B: 144, C: 138

# %% [markdown]
# ## 4. One-hot encode the data
# <p>Currently, our labels for each of the letters are encoded as categorical integers, where <code>'A'</code>, <code>'B'</code> and <code>'C'</code> are encoded as <code>0</code>, <code>1</code>, and <code>2</code>, respectively.  However, recall that Keras models do not accept labels in this format, and we must first one-hot encode the labels before supplying them to a Keras model.</p>
# <p>This conversion will turn the one-dimensional array of labels into a two-dimensional array.</p>
# <p><img src="https://assets.datacamp.com/production/project_509/img/onehot.png" alt="one-hot encoding"></p>
# <p>Each row in the two-dimensional array of one-hot encoded labels corresponds to a different image.  The row has a <code>1</code> in the column that corresponds to the correct label, and <code>0</code> elsewhere.  </p>
# <p>For instance, </p>
# <ul>
# <li><code>0</code> is encoded as <code>[1, 0, 0]</code>, </li>
# <li><code>1</code> is encoded as <code>[0, 1, 0]</code>, and </li>
# <li><code>2</code> is encoded as <code>[0, 0, 1]</code>.</li>
# </ul>

# %%
from keras.utils import np_utils
# # One-hot encode the training labels
# y_train_OH = tf.keras.utils.to_categorical([num_A_train, num_B_train, num_C_train])

# # One-hot encode the test labels
# y_test_OH = tf.keras.utils.to_categorical([num_A_test, num_B_test, num_C_test])

num_classes = len(np.unique(y_train))

# One-hot encode the training labels
y_train_OH = np_utils.to_categorical(y_train, num_classes=num_classes)

# One-hot encode the test labels
y_test_OH = np_utils.to_categorical(y_test, num_classes=num_classes)

# %% [markdown]
# ## 5. Define the model
# <p>Now it's time to define a convolutional neural network to classify the data.</p>
# <p>This network accepts an image of an American Sign Language letter as input.  The output layer returns the network's predicted probabilities that the image belongs in each category.</p>

# %%
from keras.layers import Conv2D, MaxPooling2D
from keras.layers import Flatten, Dense
from keras.models import Sequential

model = Sequential()
# First convolutional layer accepts image input
model.add(Conv2D(filters=5, kernel_size=5, padding='same', activation='relu',
                        input_shape=(50, 50, 3)))
# Add a max pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))
# Add a convolutional layer
model.add(Conv2D(filters=10, kernel_size=3, padding='same', activation='relu'))
# Add another max pooling layer
model.add(MaxPooling2D(pool_size=(2, 2)))
# Flatten and feed to output layer
model.add(Flatten())
model.add(Dense(3, activation='softmax'))

# Summarize the model
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv2d (Conv2D)             (None, 50, 50, 5)         380
#
#  max_pooling2d (MaxPooling2D  (None, 25, 25, 5)        0
#  )
#
#  conv2d_1 (Conv2D)           (None, 25, 25, 10)        460
#
#  max_pooling2d_1 (MaxPooling  (None, 12, 12, 10)       0
#  2D)
#
#  flatten (Flatten)           (None, 1440)              0
#
#  dense (Dense)               (None, 3)                 4323
#
# =================================================================
# Total params: 5,163
# Trainable params: 5,163
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## 6. Compile the model
# <p>After we have defined a neural network in Keras, the next step is to compile it! </p>

# %%
# Compile the model
model.compile(optimizer='adam',
              loss='categorical_crossentropy',
              metrics=['accuracy'])

# %% [markdown]
# ## 7. Train the model
# <p>Once we have compiled the model, we're ready to fit it to the training data.</p>

# %%
# Train the model
hist = model.fit(x_train, y_train_OH, epochs = 100)
# Out:
# Epoch 1/100
# 50/50 [==============================] - 5s 79ms/step - loss: 0.8841 - accuracy: 0.5850
# Epoch 2/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.4629 - accuracy: 0.8269
# Epoch 3/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.2655 - accuracy: 0.9069
# Epoch 4/100
# 50/50 [==============================] - 5s 104ms/step - loss: 0.1535 - accuracy: 0.9581
# Epoch 5/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0857 - accuracy: 0.9875
# Epoch 6/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0650 - accuracy: 0.9912
# Epoch 7/100
# 50/50 [==============================] - 4s 82ms/step - loss: 0.0392 - accuracy: 0.9969
# Epoch 8/100
# 50/50 [==============================] - 4s 89ms/step - loss: 0.0283 - accuracy: 0.9987
# Epoch 9/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0217 - accuracy: 0.9994
# Epoch 10/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0176 - accuracy: 0.9994
# Epoch 11/100
# 50/50 [==============================] - 5s 101ms/step - loss: 0.0167 - accuracy: 0.9987
# Epoch 12/100
# 50/50 [==============================] - 4s 70ms/step - loss: 0.0111 - accuracy: 1.0000
# Epoch 13/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0079 - accuracy: 1.0000
# Epoch 14/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0067 - accuracy: 1.0000
# Epoch 15/100
# 50/50 [==============================] - 5s 104ms/step - loss: 0.0054 - accuracy: 1.0000
# Epoch 16/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0050 - accuracy: 1.0000
# Epoch 17/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0043 - accuracy: 1.0000
# Epoch 18/100
# 50/50 [==============================] - 6s 118ms/step - loss: 0.0037 - accuracy: 1.0000
# Epoch 19/100
# 50/50 [==============================] - 5s 103ms/step - loss: 0.0034 - accuracy: 1.0000
# Epoch 20/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0028 - accuracy: 1.0000
# Epoch 21/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0027 - accuracy: 1.0000
# Epoch 22/100
# 50/50 [==============================] - 5s 102ms/step - loss: 0.0029 - accuracy: 1.0000
# Epoch 23/100
# 50/50 [==============================] - 4s 72ms/step - loss: 0.0019 - accuracy: 1.0000
# Epoch 24/100
# 50/50 [==============================] - 3s 69ms/step - loss: 0.0017 - accuracy: 1.0000
# Epoch 25/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 26/100
# 50/50 [==============================] - 5s 104ms/step - loss: 0.0014 - accuracy: 1.0000
# Epoch 27/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 28/100
# 50/50 [==============================] - 3s 68ms/step - loss: 0.0012 - accuracy: 1.0000
# Epoch 29/100
# 50/50 [==============================] - 4s 87ms/step - loss: 0.0011 - accuracy: 1.0000
# Epoch 30/100
# 50/50 [==============================] - 4s 85ms/step - loss: 9.7707e-04 - accuracy: 1.0000
# Epoch 31/100
# 50/50 [==============================] - 3s 69ms/step - loss: 9.0115e-04 - accuracy: 1.0000
# Epoch 32/100
# 50/50 [==============================] - 3s 69ms/step - loss: 8.3397e-04 - accuracy: 1.0000
# Epoch 33/100
# 50/50 [==============================] - 5s 105ms/step - loss: 7.7493e-04 - accuracy: 1.0000
# Epoch 34/100
# 50/50 [==============================] - 3s 68ms/step - loss: 7.2272e-04 - accuracy: 1.0000
# Epoch 35/100
# 50/50 [==============================] - 3s 68ms/step - loss: 6.8243e-04 - accuracy: 1.0000
# Epoch 36/100
# 50/50 [==============================] - 4s 73ms/step - loss: 7.4957e-04 - accuracy: 1.0000
# Epoch 37/100
# 50/50 [==============================] - 5s 99ms/step - loss: 6.3792e-04 - accuracy: 1.0000
# Epoch 38/100
# 50/50 [==============================] - 3s 69ms/step - loss: 5.7145e-04 - accuracy: 1.0000
# Epoch 39/100
# 50/50 [==============================] - 3s 68ms/step - loss: 5.3096e-04 - accuracy: 1.0000
# Epoch 40/100
# 50/50 [==============================] - 5s 92ms/step - loss: 4.8468e-04 - accuracy: 1.0000
# Epoch 41/100
# 50/50 [==============================] - 4s 79ms/step - loss: 5.1954e-04 - accuracy: 1.0000
# Epoch 42/100
# 50/50 [==============================] - 3s 68ms/step - loss: 5.9183e-04 - accuracy: 1.0000
# Epoch 43/100
# 50/50 [==============================] - 3s 69ms/step - loss: 4.4189e-04 - accuracy: 1.0000
# Epoch 44/100
# 50/50 [==============================] - 5s 104ms/step - loss: 3.9754e-04 - accuracy: 1.0000
# Epoch 45/100
# 50/50 [==============================] - 3s 69ms/step - loss: 3.5442e-04 - accuracy: 1.0000
# Epoch 46/100
# 50/50 [==============================] - 3s 68ms/step - loss: 3.3017e-04 - accuracy: 1.0000
# Epoch 47/100
# 50/50 [==============================] - 4s 79ms/step - loss: 3.3201e-04 - accuracy: 1.0000
# Epoch 48/100
# 50/50 [==============================] - 5s 92ms/step - loss: 3.2463e-04 - accuracy: 1.0000
# Epoch 49/100
# 50/50 [==============================] - 3s 68ms/step - loss: 3.1782e-04 - accuracy: 1.0000
# Epoch 50/100
# 50/50 [==============================] - 3s 68ms/step - loss: 2.8476e-04 - accuracy: 1.0000
# Epoch 51/100
# 50/50 [==============================] - 5s 97ms/step - loss: 2.6241e-04 - accuracy: 1.0000
# Epoch 52/100
# 50/50 [==============================] - 4s 75ms/step - loss: 2.4283e-04 - accuracy: 1.0000
# Epoch 53/100
# 50/50 [==============================] - 3s 69ms/step - loss: 2.3842e-04 - accuracy: 1.0000
# Epoch 54/100
# 50/50 [==============================] - 3s 69ms/step - loss: 2.6191e-04 - accuracy: 1.0000
# Epoch 55/100
# 50/50 [==============================] - 5s 105ms/step - loss: 2.3662e-04 - accuracy: 1.0000
# Epoch 56/100
# 50/50 [==============================] - 3s 68ms/step - loss: 2.1722e-04 - accuracy: 1.0000
# Epoch 57/100
# 50/50 [==============================] - 3s 69ms/step - loss: 1.9488e-04 - accuracy: 1.0000
# Epoch 58/100
# 50/50 [==============================] - 4s 88ms/step - loss: 1.9591e-04 - accuracy: 1.0000
# Epoch 59/100
# 50/50 [==============================] - 4s 85ms/step - loss: 1.7823e-04 - accuracy: 1.0000
# Epoch 60/100
# 50/50 [==============================] - 3s 69ms/step - loss: 1.7641e-04 - accuracy: 1.0000
# Epoch 61/100
# 50/50 [==============================] - 3s 69ms/step - loss: 1.5928e-04 - accuracy: 1.0000
# Epoch 62/100
# 50/50 [==============================] - 5s 104ms/step - loss: 1.6432e-04 - accuracy: 1.0000
# Epoch 63/100
# 50/50 [==============================] - 3s 69ms/step - loss: 1.6634e-04 - accuracy: 1.0000
# Epoch 64/100
# 50/50 [==============================] - 3s 68ms/step - loss: 1.5123e-04 - accuracy: 1.0000
# Epoch 65/100
# 50/50 [==============================] - 4s 76ms/step - loss: 1.3650e-04 - accuracy: 1.0000
# Epoch 66/100
# 50/50 [==============================] - 5s 110ms/step - loss: 1.3481e-04 - accuracy: 1.0000
# Epoch 67/100
# 50/50 [==============================] - 6s 128ms/step - loss: 1.4401e-04 - accuracy: 1.0000
# Epoch 68/100
# 50/50 [==============================] - 9s 174ms/step - loss: 1.4438e-04 - accuracy: 1.0000
# Epoch 69/100
# 50/50 [==============================] - 7s 140ms/step - loss: 1.2089e-04 - accuracy: 1.0000
# Epoch 70/100
# 50/50 [==============================] - 7s 147ms/step - loss: 1.1626e-04 - accuracy: 1.0000
# Epoch 71/100
# 50/50 [==============================] - 3s 68ms/step - loss: 1.1429e-04 - accuracy: 1.0000
# Epoch 72/100
# 50/50 [==============================] - 3s 69ms/step - loss: 1.0327e-04 - accuracy: 1.0000
# Epoch 73/100
# 50/50 [==============================] - 5s 102ms/step - loss: 9.8547e-05 - accuracy: 1.0000
# Epoch 74/100
# 50/50 [==============================] - 4s 71ms/step - loss: 1.0184e-04 - accuracy: 1.0000
# Epoch 75/100
# 50/50 [==============================] - 4s 71ms/step - loss: 9.1992e-05 - accuracy: 1.0000
# Epoch 76/100
# 50/50 [==============================] - 4s 75ms/step - loss: 8.9342e-05 - accuracy: 1.0000
# Epoch 77/100
# 50/50 [==============================] - 5s 103ms/step - loss: 9.1371e-05 - accuracy: 1.0000
# Epoch 78/100
# 50/50 [==============================] - 4s 71ms/step - loss: 8.1517e-05 - accuracy: 1.0000
# Epoch 79/100
# 50/50 [==============================] - 3s 69ms/step - loss: 7.9481e-05 - accuracy: 1.0000
# Epoch 80/100
# 50/50 [==============================] - 5s 96ms/step - loss: 7.6548e-05 - accuracy: 1.0000
# Epoch 81/100
# 50/50 [==============================] - 4s 79ms/step - loss: 7.3365e-05 - accuracy: 1.0000
# Epoch 82/100
# 50/50 [==============================] - 3s 69ms/step - loss: 7.0213e-05 - accuracy: 1.0000
# Epoch 83/100
# 50/50 [==============================] - 3s 69ms/step - loss: 6.9842e-05 - accuracy: 1.0000
# Epoch 84/100
# 50/50 [==============================] - 5s 105ms/step - loss: 7.1260e-05 - accuracy: 1.0000
# Epoch 85/100
# 50/50 [==============================] - 3s 69ms/step - loss: 6.2281e-05 - accuracy: 1.0000
# Epoch 86/100
# 50/50 [==============================] - 3s 70ms/step - loss: 6.4559e-05 - accuracy: 1.0000
# Epoch 87/100
# 50/50 [==============================] - 4s 85ms/step - loss: 6.2117e-05 - accuracy: 1.0000
# Epoch 88/100
# 50/50 [==============================] - 4s 87ms/step - loss: 5.8068e-05 - accuracy: 1.0000
# Epoch 89/100
# 50/50 [==============================] - 3s 69ms/step - loss: 5.4122e-05 - accuracy: 1.0000
# Epoch 90/100
# 50/50 [==============================] - 3s 69ms/step - loss: 5.4224e-05 - accuracy: 1.0000
# Epoch 91/100
# 50/50 [==============================] - 5s 105ms/step - loss: 5.1020e-05 - accuracy: 1.0000
# Epoch 92/100
# 50/50 [==============================] - 4s 75ms/step - loss: 4.9851e-05 - accuracy: 1.0000
# Epoch 93/100
# 50/50 [==============================] - 3s 69ms/step - loss: 4.7440e-05 - accuracy: 1.0000
# Epoch 94/100
# 50/50 [==============================] - 4s 80ms/step - loss: 4.7751e-05 - accuracy: 1.0000
# Epoch 95/100
# 50/50 [==============================] - 5s 93ms/step - loss: 4.8292e-05 - accuracy: 1.0000
# Epoch 96/100
# 50/50 [==============================] - 3s 68ms/step - loss: 4.2649e-05 - accuracy: 1.0000
# Epoch 97/100
# 50/50 [==============================] - 3s 68ms/step - loss: 4.5452e-05 - accuracy: 1.0000
# Epoch 98/100
# 50/50 [==============================] - 5s 98ms/step - loss: 4.1136e-05 - accuracy: 1.0000
# Epoch 99/100
# 50/50 [==============================] - 4s 74ms/step - loss: 3.9580e-05 - accuracy: 1.0000
# Epoch 100/100
# 50/50 [==============================] - 3s 69ms/step - loss: 3.8499e-05 - accuracy: 1.0000

# %% [markdown]
# ## 8. Test the model
# <p>To evaluate the model, we'll use the test dataset.  This will tell us how the network performs when classifying images it has never seen before!</p>
# <p>If the classification accuracy on the test dataset is similar to the training dataset, this is a good sign that the model did not overfit to the training data.  </p>

# %%
# Obtain accuracy on test set
score = model.evaluate(x=x_test,
                       y=y_test_OH,
                       verbose=0)
print('Test accuracy:', score[1])
# Out:
# Test accuracy: 1.0

# %% [markdown]
# ## 9. Visualize mistakes
# <p>Hooray!  Our network gets very high accuracy on the test set!  </p>
# <p>The final step is to take a look at the images that were incorrectly classified by the model.  Do any of the mislabeled images look relatively difficult to classify, even to the human eye?  </p>
# <p>Sometimes, it's possible to review the images to discover special characteristics that are confusing to the model.  However, it is also often the case that it's hard to interpret what the model had in mind!</p>

# %%
# Get predicted probabilities for test dataset
y_probs = model.predict(x_test)

# Get predicted labels for test dataset
y_preds = np.argmax(y_probs, axis=1)

# Indices corresponding to test images which were mislabeled
bad_test_idxs = np.where(y_preds != y_test)[0]

# Print mislabeled examples
fig = plt.figure(figsize=(25,4))
for i, idx in enumerate(bad_test_idxs):
    ax = fig.add_subplot(2, np.ceil(len(bad_test_idxs)/2), i + 1, xticks=[], yticks=[])
    ax.imshow(np.squeeze(x_test[idx]))
    ax.set_title("{} (pred: {})".format(labels[y_test[idx]], labels[y_preds[idx]]))
# Out:
# 13/13 [==============================] - 0s 27ms/step

# %% [markdown]
# **Conclusion**

# %% [markdown]
# In this project, a CNN-based classification model was successfully developed to classify ASL letters. The model's ability to accurately classify individual letters lays the foundation for more complex translation systems, aiding communication between hearing and non-hearing individuals.
